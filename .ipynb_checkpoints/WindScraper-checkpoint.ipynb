# %%
from bs4 import BeautifulSoup
import requests

#Gets text from url of choice
url = "https://tides4fishing.com/us/california/south-san-francisco/forecast/wind"
#requests gets text from url
txt = requests.get(url)

doc = BeautifulSoup(txt.text, "html.parser")

print(doc.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <!-- mar2 -->
#  <head>
#   <title>
#    Wind in South San Francisco. Wind forecast hour by hour, wind speed and wind direction in South San Francisco.
#   </title>
#   <meta charset="utf-8"/>
#   <link href="https://tides4fishing.com/us/california/south-san-francisco/forecast/wind/amp" rel="amphtml"/>
#   <meta content="#153152" name="theme-color"/>
#   <meta content="Know the wind forecast in South San Francisco and the wind forecast for the next days" name="description"/>
#   <meta content="width=device-width, initial-scale=1, user-scalable=yes" name="viewport"/>
#   <meta content="Wind in South San Francisco. Wind forecast hour by hour, wind speed and wind direction in South San Francisco." property="og:title"/>
#   <meta content="https://tides4fishing.com/banners/tides4fishing_square_250x250.jpg" property="og:image"/>
#   <meta content="Know the wind forecast in South San Francisco and the wind forecast for the next days" property="og:description"/>
#   <meta content="https://tides4fishing.com/us/california/south-san-francisco/forecast/wind" property="og:url"/>
#   <link href="https://tides4fishing.com/favicon.ico" rel="shortcut icon"/>
#   <style>
#    /*! normalize.css v2.1.0 | MIT License | git.io/normalize */article,aside,details,figcaption,figure,footer,header,hgroup,main,nav,section,summary{display:block}audio,canvas,video{display:inline-block}audio:not([controls]){display:none;height:0}[hidden]{display:none}html{font-family:sans-serif;-webkit-text-size-adjust:100%;-ms-text-size-adjust:100%}body{margin:0}a:focus{outline:thin dotted}a:active,a:hover{outline:0}h1{font-size:2em;margin:.67em 0}abbr[title]{border-bottom:1px dotted}b,strong{font-weight:700}dfn{font-style:italic}hr{-moz-box-sizing:content-box;box-sizing:content-box;height:0}mark{background:#ff0;color:#000}code,kbd,pre,samp{font-family:monospace,serif;font-size:1em}pre{white-space:pre-wrap}q{quotes:"\201C" "\201D" "\2018" "\2019"}small{font-size:80%}sub,sup{font-size:75%;line-height:0;position:relative;vertical-align:baseline}sup{top:-.5em}sub{bottom:-.25em}img{border:0}svg:not(:root){overflow:hidden}figure{margin:0}fieldset{border:1px solid silver;margin:0 2px;padding:.35em .625em .75em}legend{border:0;padding:0}button,input,select,textarea{font-family:inherit;font-size:100%;margin:0}button,input{line-height:normal}button,select{text-transform:none}button,html input[type=button],input[type=reset],input[type=submit]{-webkit-appearance:button;cursor:pointer}button[disabled],html input[disabled]{cursor:default}input[type=checkbox],input[type=radio]{box-sizing:border-box;padding:0}input[type=search]{-webkit-appearance:textfield;-moz-box-sizing:content-box;-webkit-box-sizing:content-box;box-sizing:content-box}input[type=search]::-webkit-search-cancel-button,input[type=search]::-webkit-search-decoration{-webkit-appearance:none}button::-moz-focus-inner,input::-moz-focus-inner{border:0;padding:0}textarea{overflow:auto;vertical-align:top}table{border-collapse:collapse;border-spacing:0}.nautide{position:relative;width:100%;overflow:hidden;background-color:#282828}.linea_top{width:100%;height:3px;background:linear-gradient(to right,#3d27ed,#9359fd,#5ee4fb)}.nautide_content{position:relative;width:90%;margin:20px auto;padding-bottom:25px}.logo_nautide{position:relative;display:inline;width:69px;height:69px}.nautide_name{position:absolute;top:2px;left:89px}.nautide_description{position:absolute;top:29px;left:89px;font-family:Roboto,sans-serif;color:#ddd;font-size:1em;text-overflow:ellipsis}.name_nautide{width:112px;top:12px;left:20px}.nautide_content2{position:relative;width:90%;margin:20px auto}.nautide_puntuacion{position:relative;display:inline-table;background-repeat:no-repeat;background-position:right;width:85px;text-align:right;padding-right:20px;background-size:20px;font-family:Roboto,sans-serif;color:#888;font-size:.9em;bottom:-5px}.nautide_puntuacion_estrellas{position:absolute;top:-16px;right:5px;text-align:right}.estrella_puntuacion{position:relative;width:9px;display:inline-table}.usuario_puntuacion{position:relative;width:15px;display:inline-table;top:3px}.botones_market{position:relative;margin-top:-20px;margin-left:90px;padding-top:5px;height:40px;width:270px}.market_button1{width:90px;margin-right:5px}.market_button2{width:90px}@media all and (min-width:340px){.market_button1{width:110px}.market_button2{width:110px}}@media all and (min-width:370px){.botones_market{margin-top:-30px}.market_button1{width:120px;margin-right:10px}.market_button2{width:120px}}@media all and (min-width:450px){.market_button1{margin-right:20px}.nautide_content{width:80%;max-width:440px;margin-bottom:15px}.nautide_content2{width:80%;max-width:440px;margin-top:0}}@media all and (min-width:850px){.nautide2{position:relative;width:90%;margin:0 auto;height:100px;max-width:800px}.nautide_content{position:absolute;width:59%;left:0;margin:20px auto}.nautide_content2{position:absolute;width:32%;right:0;bottom:0}.botones_market{margin-left:-55px;padding-top:5px}.nautide_puntuacion{position:absolute;top:-45px;right:0;width:150px}.nautide_puntuacion_estrellas{position:absolute;top:-6px;right:50px;text-align:right}}.anuncio_modo_test{backgr ...
# #cabecera_contenido2_banner_mareas { background-image: url(/assets/svg/banner/ayuda_mareas_silueta.svg) }
# .menu_seleccionar_ancla_azul_seleccionado {	background-image: url(/assets/svg/ic_radio_azul_selected.svg) !important }
# .menu_seleccionar_ancla_fase_lunar_seleccionado { background-image: url(/assets/svg/ic_radio_amarillo_selected.svg) }
# .menu_seleccionar_ancla_azul { background-image: url(/assets/svg/ic_radio_azul.svg) }
# .menu_seleccionar_ancla_azul:hover { background-image: url(/assets/svg/ic_radio_azul_selected.svg) !important }
# .menu_seleccionar_ancla_fase_lunar { background-image: url(/assets/svg/ic_radio_amarillo.svg) !important }
# .menu_seleccionar_ancla_fase_lunar:hover { background-image: url(/assets/svg/ic_radio_amarillo_selected.svg) !important }
# #cabecera_contenido2_luna {	background-image: url(/assets/svg/banner/calendario_lunar_luna.svg) }
# #cabecera_contenido2 { background-image: url(/assets/svg/banner/calendario_lunar_fondo.svg) }
# #cabecera_contenido2_fondo1 { background-image: url(/assets/svg/banner/calendario_lunar_silueta.svg) }
# #seccion_menu_eclipses { background-image: url(/assets/svg/ic_eclipse.svg) }
# #seccion_menu_z1 { background-image: url(/assets/svg/ic_mes1.svg) }
# #seccion_menu_z2 { background-image: url(/assets/svg/ic_mes2.svg) }
# #seccion_menu_z3 { background-image: url(/assets/svg/ic_mes3.svg) }
# #seccion_menu_z4 { background-image: url(/assets/svg/ic_mes4.svg) }
# #seccion_menu_z5 { background-image: url(/assets/svg/ic_mes5.svg) }
# #seccion_menu_z6 { background-image: url(/assets/svg/ic_mes6.svg) }
# #seccion_menu_z7 { background-image: url(/assets/svg/ic_mes7.svg) }
# #seccion_menu_z8 { background-image: url(/assets/svg/ic_mes8.svg) }
# #seccion_menu_z9 { background-image: url(/assets/svg/ic_mes9.svg) }
# #seccion_menu_z10 {	background-image: url(/assets/svg/ic_mes10.svg) }
# #seccion_menu_z11 {	background-image: url(/assets/svg/ic_mes11.svg) }
# #seccion_menu_z12 {	background-image: url(/assets/svg/ic_mes12.svg) }
# #cabecera_contenido2 { background-image: url(/assets/svg/banner/estacion_fondo.svg)	}
# #cabecera_contenido2_fondo1 { background-image: url(/assets/svg/banner/estacion_silueta.svg) }
# .menu_seleccionar_ancla_pais { background-image: url('/assets/svg/ic_radio.svg') }
# .menu_seleccionar_ancla_pais:hover { background-image: url("/assets/svg/ic_radio_selected.svg") !important }
# #cabecera_contenido2 { background-image: url(/assets/svg/banner/tallas_minimas_fondo.svg) }
# #cabecera_contenido2_banner { background-image: url(/assets/svg/banner/tallas_minimas_silueta.svg) }
# #seccion_menu_tallas_minimas { background-image: url(/assets/svg/ic_tallas_minimas.svg) }
# #cabecera_contenido2 { background-image: url(/assets/svg/banner/tiempo_fondo.svg) }
# #cabecera_contenido2_banner { background-image: url(/assets/svg/banner/tiempo_silueta.svg) }
#
# .menu_seleccionar_seccion {	background-image: url(/assets/svg/circulo_seleccionar_seccion.svg) }
# #pie1 {	background-image: url(/assets/img/fondo_pie.png) }
# .SelectStyle:after { background-image: url('/assets/img/graph/cal/flecha_select.svg') }
# .radio { background: url(/assets/img/radio_2.png) no-repeat }
# #radio_0 { background-image: url(/assets/img/radio_0.png) }
# #radio_1 { background-image: url(/assets/img/radio_1.png) }
# #radio_2 { background-image: url(/assets/img/radio_2.png) }
# .l_grafico_mareas_responsive_ico_salida_sol { background-image: url("/assets/svg/ic_salida_sol_leyenda.svg") }
# .l_grafico_mareas_responsive_ico_puesta_sol { background-image: url("/assets/svg/ic_puesta_sol_leyenda.svg") }
# .grafico_triangulo_coeficiente_vacio { background-image: url(/assets/img/graph/gc/triangulo_vacio.svg) }
# .grafico_triangulo_coeficiente_lleno { background-image: url(/assets/img/graph/gc/triangulo_lleno.svg) }
# .l_grafico_alturas_responsive_coef_fondo { background-image: url(/assets/img/graph/gc/triangulo_vacio.svg) }
# .l_grafico_alturas_responsive_coef { background-image: url(/assets/img/graph/gc/triangulo_lleno.svg) }
# .l_grafico_solunar_responsive_ico_salida_sol { background-image: url("/assets/svg/ic_salida_sol_leyenda.svg") }
# .l_grafico_solunar_responsive_ico_puesta_sol { background-image: url("/assets/svg/ic_puesta_sol_leyenda.svg") }
# .l_grafico_solunar_responsive_ico_salida_luna {	background-image: url("/assets/svg/ic_salida_luna_leyenda.svg") }
# .l_grafico_solunar_responsive_ico_puesta_luna {	background-image: url("/assets/svg/ic_puesta_luna_leyenda.svg") }
# #grafico_tiempo_humedad_lleno {	background-image: url(/assets/img/graph/et/humedad_lleno.svg) }
# #grafico_tiempo_humedad_vacio {	background-image: url(/assets/img/graph/et/humedad_vacio.svg) }
# @media all and (min-width: 500px) {
# .l_grafico_alturas_responsive_punto_azul_hora_globo { background-image: url(/assets/img/graph/gm/globo_altura_azul.svg) }
# .l_grafico_alturas_responsive_punto_rojo_hora_globo { background-image: url(/assets/img/graph/gm/globo_altura_rojo.svg) }
# }
# @media all and (min-width: 650px) {
# .l_grafico_coef_globo_bajo_verde { background-image: url(/assets/img/graph/gc/globo_coef_bajo_verde.svg) }
# .l_grafico_coef_globo_bajo_amarillo { background-image: url(/assets/img/graph/gc/globo_coef_bajo_amarillo.svg) }
# .l_grafico_coef_globo_bajo_naranja { background-image: url(/assets/img/graph/gc/globo_coef_bajo_naranja.svg) }
# .l_grafico_coef_globo_bajo_rojo { background-image: url(/assets/img/graph/gc/globo_coef_bajo_rojo.svg) }
# .l_grafico_coef_globo_alto_verde { background-image: url(/assets/img/graph/gc/globo_coef_alto_verde.svg) }
# .l_grafico_coef_globo_alto_amarillo { background-image: url(/assets/img/graph/gc/globo_coef_alto_amarillo.svg) }
# .l_grafico_coef_globo_alto_naranja { background-image: url(/assets/img/graph/gc/globo_coef_alto_naranja.svg) }
# .l_grafico_coef_globo_alto_rojo { background-image: url(/assets/img/graph/gc/globo_coef_alto_rojo.svg) }
# }
# #cabecera_contenido2_solunar { background-image: url(/assets/svg/banner/ayuda_solunar_fondo.svg) }
# #cabecera_contenido2_banner_tablas_solunares { background-image: url(/assets/svg/banner/ayuda_solunar_silueta.svg) }
# .ic_arrow_azul:before {	background: url("/assets/svg/ic_arrow_azul.svg") no-repeat }
# .ic_arrow_amarillo:before {	background: url("/assets/svg/ic_arrow_amarillo.svg") no-repeat }
# .salida:before { background: url("/assets/svg/calendario_lunar/salida.svg") no-repeat }
# .puesta:before { background: url("/assets/svg/calendario_lunar/puesta.svg") no-repeat }
# .distancia:before {	background: url("/assets/svg/calendario_lunar/distancia.svg") no-repeat }
# .duracion:before { background: url("/assets/svg/calendario_lunar/duracion.svg") no-repeat }
# .iluminacion:before { background: url("/assets/svg/calendario_lunar/iluminacion.svg") no-repeat }
# .grafico_oleaje_actual_leyenda { background: url(/assets/img/graph/et/fondo_olas.svg) repeat-x bottom #eeeeee }
# .circulo_estado_grafico_barometro1_activo {	background-image: url("/assets/svg/ic_presion_activa_muy_bueno.svg") }
# .circulo_estado_grafico_barometro2_activo {	background-image: url("/assets/svg/ic_presion_activa_bueno.svg") }
# .circulo_estado_grafico_barometro3_activo {	background-image: url("/assets/svg/ic_presion_activa_malo.svg") }
# #seccion_menu_mapa_meteorologico { background-image: url(/assets/svg/mapa_meteorologico.svg) }
# #cabecera_contenido2_mareas{position:relative;width:100%;padding-top:190px;background-size:cover}#cabecera_contenido2_banner_mareas{position:absolute;width:100%;height:100%;top:0;background-size:450px;background-repeat:no-repeat;z-index:10}.menu_seleccionar_ancla{height:37px;line-height:37px}.menu_seleccionar_ancla_azul{color:#000;padding-left:60px}.menu_seleccionar_ancla_azul_seleccionado{color:#000;padding-left:60px}#header_prevision{width:358px}body{width:100%;margin:0;padding:0;font-size:1em;background-color:#fff;color:#000;overflow:visible;font-family:Roboto,sans-serif}#header2_prevision{position:relative;height:60px;width:100%;padding-right:19px;padding-left:19px;margin:0 auto;text-align:justify;display:none}#header2_prevision a{text-decoration:none}#cabecera_contenido2{position:relative;width:100%;padding-top:190px;background-size:cover}#cabecera_contenido2_banner{position:absolute;width:100%;height:100%;top:0;background-size:450px;background-repeat:no-repeat;z-index:10}@media all and (min-width:1155px){#header2_prevision{display:block}}.f_enlace{position:relative;padding:10px 40px 10px 20px}.a_enlace{text-decoration:none;color:#455a64}.f_enlace>.enlace{font-weight:lighter;font-size:1em;line-height:20px}.f_fecha{position:relative;min-height:95px}.f_fecha>.f_circulo>.dia{margin-right:5px;display:block;font-weight:bolder;font-size:1.1em;line-height:18px}.f_fecha>.f_circulo>.mes{display:none;font-size:1.1em;line-height:16px;font-weight:700;margin-right:5px}.f_fecha>.f_info_dia_ajustes{position:relative;padding-left:20px;text-align:left;font-family:Roboto,sans-serif;padding-top:20px;padding-right:20px}.fase_info_ajuste{font-size:.9em!important}.f_fecha>.f_info_dia_ajustes>.text_dia{display:block;font-weight:700;font-size:1.2em;line-height:28px;color:#263238}.fase_text_dia{font-size:1.2em!important}.f_fecha>.f_info_dia>.info{display:block;font-size:1em;line-height:20px}.f_fecha>.f_info_dia_ajustes>.info{display:block;font-size:1em;line-height:20px}.icon_cabecera_prediccion{width:25px}.nota_precipitacion{font-style:italic;font-size:.9em;padding-top:10px;padding-bottom:20px}.f_datos{position:relative;min-height:128px;background-color:#eceff1;padding:30px 10px 0 20px}.f_datos1{position:relative;width:100%;padding-bottom:15px}.f_datos_text{display:inline-flex;width:49%;padding:0 10px 0 0;font-size:.9em}.f_datos2{display:inline-flex;width:49%;padding-right:10px;font-size:.9em}.f_datos2 span{position:relative;display:inline-block;padding:10px 2px 10px 0}.f_datos_tit{display:inline-flex;width:100%;padding:0 10px 0 0;font-size:1em}.f_datos3{display:block;width:100%;padding-right:10px;font-size:.9em}.f_datos_tit2{position:relative;padding-left:10px}.grafico_amplitud_barra{position:relative;width:100%;height:32px;background-color:#cdd5da;border-radius:2px;margin:15px auto}.grafico_amplitud_barra_relleno{position:relative;display:flex;justify-content:left;align-items:center;width:80%;height:100%;border-radius:2px 0 0 2px;text-align:center;color:#fdfcfc;line-height:45px;padding-left:10px;padding-right:10px;font-size:1.1em;min-width:65px;white-space:nowrap}.coef_media_menos_50{background-color:#73fe62;color:#575757}.coef_media_50_70{background-color:#ff0;color:#575757}.coef_media_70_90{background-color:#ff8600;color:#fff}.coef_media_mas_90{background-color:#fe005a;color:#fff}.f_hora{position:relative;display:flex;justify-content:center;align-items:center;font-size:1.2em;background-color:#ff5722;width:95px;height:30px;padding:2px 0;color:#fff;border-radius:5px;bottom:5px;margin-left:5px;text-align:center}.f_hoara_lila{background-color:#3f51b5!important}.f_tabla_mareas{width:100%;text-align:center;margin-top:15px;margin-bottom:18px}.f_tabla_mareas th{font-weight:400;font-size:1em;color:#607d8b;line-height:30px}.f_tabla_mareas td{line-height:30px}.f_tabla_mareas td.ico{padding-left:10px}.f_tabla_mareas .azul{color:#2196f3}.f_tabla_mareas .rojo{color:#ff1744}.f_text{position:relative;background-color:#fff;padding:25px 15px}.f_pez{position:re ...
#   </style>
#  </head>
#  <body>
#   <!-- 7.3 -->
#   <script>
#    var JS_IDIOMA = "en";
# 		var JS_LINK_ROOT = "https://tides4fishing.com";
# 		var JS_RUTA_ASSETS = "/assets/";
# 		var CONF_FORMATO_HORA = 0;
#         		  window.google_analytics_uacct = "UA-8166479-2";
#   </script>
#   <div id="cookies">
#    <div id="texto_cookies">
#     Tides4fishing
#     <strong>
#      cookies
#     </strong>
#     are used to personalise content and ads, save your recent fishing sites and remember your display settings. We also share information about your use of our site with our social media, advertising and analytics partners.
#    </div>
#    <div id="botones_cookies">
#     <a href="https://tides4fishing.com/legal-notice">
#      See details
#     </a>
#     <a onclick="CerrarCookies();" style="margin-left:15px">
#      OK
#     </a>
#    </div>
#   </div>
#   <a class="to_top_sticky2" data-easing="easeInOutCubic" data-scroll="" data-speed="500" data-url="false" href="https://tides4fishing.com/us/california/south-san-francisco/forecast/wind#to_top" id="to_top_sticky" onclick="BeforeScroll()">
#    <img src="/assets/svg/ic_btn_to_top3.svg"/>
#   </a>
#   <div>
#    <a data-easing="easeInOutCubic" data-scroll="" data-speed="500" data-url="false" href="https://tides4fishing.com/us/california/south-san-francisco/forecast/wind#to_top" id="volver_arriba" onclick="BeforeScroll()">
#     <img alt="tide table" height="16" src="/assets/svg/ic_btn_to_top2.svg" width="24"/>
#    </a>
#   </div>
#   <div id="to_top">
#   </div>
#   <div id="boton_menu_flotante" onclick="AbrirCerrarMenu();">
#    <img alt="" height="18" src="/assets/svg/menu55.svg" width="18"/>
#   </div>
#   <header class="header header_reducido header--fixed hide-from-print" id="header">
#    <div id="header1">
#     <div id="boton_menu" onclick="AbrirCerrarMenu();">
#      <div id="boton_menu2">
#       <div id="raya_menu1">
#       </div>
#       <div id="raya_menu2">
#       </div>
#       <div id="raya_menu3">
#       </div>
#      </div>
#     </div>
#     <div id="header1_2">
#      <div id="nombre_estacion">
#       <a class="migas" href="https://tides4fishing.com/na" title="tides for North America">
#        North America
#       </a>
#       <span class="nombre_estacion_lugar_separador">
#        <img alt="" height="8" src="/assets/svg/separador_migas.svg" width="7"/>
#       </span>
#       <a class="migas" href="https://tides4fishing.com/us" title="tides for United States">
#        United States
#       </a>
#       <span class="nombre_estacion_lugar_separador">
#        <img alt="" height="8" src="/assets/svg/separador_migas.svg" width="7"/>
#       </span>
#       <a class="migas" href="https://tides4fishing.com/us/california" title="tides for California">
#        California
#       </a>
#       <span class="nombre_estacion_lugar_separador">
#        <img alt="" height="8" src="/assets/svg/separador_migas.svg" width="7"/>
#       </span>
#       <a class="migas_permanente" href="https://tides4fishing.com/us/california/south-san-francisco" title="tides for South San Francisco">
#        South San Francisco
#        <div class="migas_pescado_c_img">
#         <img alt="South San Francisco fishing" class="migas_pescado_img" height="16" src="/assets/svg/fishing.svg" width="33"/>
#        </div>
#       </a>
#      </div>
#      <div id="boton_buscar">
#       <a href="https://tides4fishing.com" title="tides table">
#        <img alt="tides table" height="24" src="/assets/svg/ic_lupa.svg" width="24"/>
#       </a>
#      </div>
#      <div id="boton_ajustes">
#       <a href="https://tides4fishing.com/settings">
#        <img alt="Help" height="21" src="/assets/svg/settings.svg" width="21"/>
#       </a>
#      </div>
#      <div class="dl-trigger" id="fondo_menu_ajustes" onclick="ForzarCerrarMenu(); AbrirCerrarAjustes();">
#      </div>
#      <div class="dl-menuwrapper" id="dl-menu" title="display settings">
#       <div class="dl-trigger" id="boton_menu_ajustes" onclick="ForzarCerrarMenu(); AbrirCerrarAjustes();">
#        <div id="leyenda_boton_opciones">
#         Settings
#        </div>
#        <div id="boton_opciones">
#         <img alt="" height="16" src="/assets/svg/ic_ajustes.svg" width="4"/>
#        </div>
#       </div>
#       <button class="dl-trigger" id="boton_menu_ajustes_abrir">
#       </button>
#       <form action="https://tides4fishing.com/us/california/south-san-francisco" id="form_configuracion" method="post">
#        <input id="parametros_configuracion" name="t4f_v" type="hidden" value="11000000"/>
#       </form>
#       <ul class="dl-menu">
#        <li>
#         <a href="javascript:void(0)">
#          Change language
#         </a>
#         <img alt="" height="12" src="/assets/svg/flecha_der_clarito.svg" width="12"/>
#         <ul class="dl-submenu" id="idiomas_ajustes">
#          <li>
#           <a href="https://tides4fishing.com">
#            <img alt="active" class="confirmacion_conf" height="10" src="/assets/svg/check34.svg" width="12"/>
#            English
#           </a>
#          </li>
#          <li>
#           <a href="https://tablademareas.com">
#            Spanish
#           </a>
#          </li>
#          <li>
#           <a href="https://mareespeche.com">
#            French
#           </a>
#          </li>
#          <li>
#           <a href="https://tabuademares.com">
#            Portuguese
#           </a>
#          </li>
#          <li>
#           <a href="https://meteopesca.com">
#            Italian
#           </a>
#          </li>
#          <li>
#           <a href="https://gezeitenfisch.com">
#            German
#           </a>
#          </li>
#          <li>
#           <a href="https://choseki.com">
#            Japanese
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li>
#         <a href="javascript:void(0)">
#          Date and Time Settings
#         </a>
#         <img alt="" height="12" src="/assets/svg/flecha_der_clarito.svg" width="12"/>
#         <ul class="dl-submenu">
#          <li>
#           <a href="javascript:void(0)">
#            Date Format
#           </a>
#           <img alt="" height="12" src="/assets/svg/flecha_der_clarito.svg" width="12"/>
#           <ul class="dl-submenu">
#            <li>
#             <a href="javascript:void(0)" onclick="CambiarConfiguracion(1,0)">
#              dd/mm/yyyy
#             </a>
#            </li>
#            <li>
#             <a href="javascript:void(0)" onclick="CambiarConfiguracion(1,1)">
#              <img alt="active" class="confirmacion_conf" height="10" src="/assets/svg/check34.svg" width="12"/>
#              mm/dd/yyyy
#             </a>
#            </li>
#            <li>
#             <a href="javascript:void(0)" onclick="CambiarConfiguracion(1,2)">
#              yyyy/mm/dd
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li>
#           <a href="javascript:void(0)">
#            First day of the week
#           </a>
#           <img alt="" height="12" src="/assets/svg/flecha_der_clarito.svg" width="12"/>
#           <ul class="dl-submenu">
#            <li>
#             <a href="javascript:void(0)" onclick="CambiarConfiguracion(2,1)">
#              Monday
#             </a>
#            </li>
#            <li>
#             <a href="javascript:void(0)" onclick="CambiarConfiguracion(2,0)">
#              <img alt="active" class="confirmacion_conf" height="10" src="/assets/svg/check34.svg" width="12"/>
#              Sunday
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li>
#           <a href="javascript:void(0)">
#            Time format  (12-hour / 24-hour)
#           </a>
#           <img alt="" height="12" src="/assets/svg/flecha_der_clarito.svg" width="12"/>
#           <ul class="dl-submenu">
#            <li>
#             <a href="javascript:void(0)" onclick="CambiarConfiguracion(3,0)">
#              <img alt="active" class="confirmacion_conf" height="10" src="/assets/svg/check34.svg" width="12"/>
#              12-hour  (am/pm)
#             </a>
#            </li>
#            <li>
#             <a href="javascript:void(0)" onclick="CambiarConfiguracion(3,1)">
#              24-hour
#             </a>
#            </li>
#           </ul>
#          </li>
#         </ul>
#        </li>
#        <li>
#         <a href="javascript:void(0)">
#          Default units
#         </a>
#         <img alt="" height="12" src="/assets/svg/flecha_der_clarito.svg" width="12"/>
#         <ul class="dl-submenu">
#          <li>
#           <a href="javascript:void(0)">
#            Height of the tides
#           </a>
#           <img alt="" height="12" src="/assets/svg/flecha_der_clarito.svg" width="12"/>
#           <ul class="dl-submenu">
#            <li>
#             <a href="javascript:void(0)" onclick="CambiarConfiguracion(5,1)">
#              Meters (m)
#             </a>
#            </li>
#            <li>
#             <a href="javascript:void(0)" onclick="CambiarConfiguracion(5,0)">
#              <img alt="active" class="confirmacion_conf" height="10" src="/assets/svg/check34.svg" width="12"/>
#              Feet (ft)
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li>
#           <a href="javascript:void(0)">
#            Weather units
#           </a>
#           <img alt="" height="12" src="/assets/svg/flecha_der_clarito.svg" width="12"/>
#           <ul class="dl-submenu">
#            <li>
#             <a href="javascript:void(0)" onclick="CambiarConfiguracion(6,1)">
#              °C, km/h, hPa
#             </a>
#            </li>
#            <li>
#             <a href="javascript:void(0)" onclick="CambiarConfiguracion(6,0)">
#              <img alt="active" class="confirmacion_conf" height="10" src="/assets/svg/check34.svg" width="12"/>
#              °F, mph, inches
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li>
#           <a href="javascript:void(0)">
#            Distance between stars
#           </a>
#           <img alt="" height="12" src="/assets/svg/flecha_der_clarito.svg" width="12"/>
#           <ul class="dl-submenu">
#            <li>
#             <a href="javascript:void(0)" onclick="CambiarConfiguracion(7,1)">
#              kilometers (km)
#             </a>
#            </li>
#            <li>
#             <a href="javascript:void(0)" onclick="CambiarConfiguracion(7,0)">
#              <img alt="active" class="confirmacion_conf" height="10" src="/assets/svg/check34.svg" width="12"/>
#              Astronomic unit (AU)
#             </a>
#            </li>
#           </ul>
#          </li>
#         </ul>
#        </li>
#        <li>
#         <a href="javascript:void(0)">
#          My recent sites
#         </a>
#         <img alt="" height="12" src="/assets/svg/flecha_der_clarito.svg" width="12"/>
#         <ul class="dl-submenu">
#          <li>
#           <a href="https://tides4fishing.com/us/california/south-san-francisco">
#            South San Francisco
#           </a>
#          </li>
#         </ul>
#        </li>
#       </ul>
#      </div>
#     </div>
#    </div>
#    <div id="header2_prevision">
#     <a href="https://tides4fishing.com/us/california/south-san-francisco/forecast">
#      <div id="header_prevision">
#       WEEKLY FORECAST
#      </div>
#     </a>
#     <div id="hora_header">
#      <a href="https://tides4fishing.com/us/california/south-san-francisco" rel="nofollow" title="refresh">
#       <img alt="refresh" height="15" id="recargar_hora" src="/assets/svg/recargar_hora.svg" width="14"/>
#      </a>
#      <div id="hora_header2">
#      </div>
#      <div id="separador_hora_header2">
#      </div>
#      <div id="utc_hora">
#       UTC
#       <span class="utc_bold">
#        -7
#       </span>
#      </div>
#      <div id="lugar_hora">
#       <span class="utc_bold">
#        California
#       </span>
#       (	US)
#      </div>
#     </div>
#     <div id="cuadro_cambiar_hora">
#      <div id="circulo_menu">
#       <img alt="time change" height="7" src="/assets/svg/ic_arrow_down.svg" width="12"/>
#      </div>
#      <div id="cambio_hora">
#       time change
#      </div>
#      <div id="dias_cambio_hora">
#       <span class="utc_bold">
#        202 days
#       </span>
#       <span class="utc_verano">
#        (UTC -8)
#       </span>
#      </div>
#     </div>
#     <div id="justificar_header2">
#     </div>
#    </div>
#   </header>
#   <div id="fondo_menu_lateral">
#   </div>
#   <div id="menu_lateral">
#    <div class="boton_atras_menu">
#     <img onclick="AbrirCerrarMenu();" src="/assets/svg/flecha_atras_IOS.svg"/>
#    </div>
#    <a href="#inicio_menu_ancla" id="flecha_arriba_menu">
#    </a>
#    <a href="#fin_menu_ancla" id="flecha_abajo_menu">
#    </a>
#    <div id="inicio_menu_ancla">
#    </div>
#    <div id="menu_lateral2">
#     <div class="logo_menu logo_menu_sin_margen">
#      <a data-easing="easeInOutCubic" data-scroll="" data-speed="500" data-url="false" href="https://tides4fishing.com/us/california/south-san-francisco/forecast/wind#to_top">
#       <img alt="tide table" class="cursor_up" src="/assets/svg/logo_en.svg"/>
#      </a>
#     </div>
#     <div class="cabecera_seccion cabecera_seccion_lugar cabecera_seccion_lugar_margen">
#      Weekly forecast
#      <div class="cabecera_contenido2_enlace_esquina">
#      </div>
#     </div>
#     <a class="menu_seleccionar_ancla menu_seleccionar_ancla_azul" href="https://tides4fishing.com/us/california/south-san-francisco/forecast/tides">
#      Tides
#     </a>
#     <a class="menu_seleccionar_ancla menu_seleccionar_ancla_azul" href="https://tides4fishing.com/us/california/south-san-francisco/forecast/fishing">
#      Fishing
#     </a>
#     <a class="menu_seleccionar_ancla menu_seleccionar_ancla_azul" href="https://tides4fishing.com/us/california/south-san-francisco/forecast/sunrise-sunset">
#      Sunrise and sunset
#     </a>
#     <a class="menu_seleccionar_ancla menu_seleccionar_ancla_azul" href="https://tides4fishing.com/us/california/south-san-francisco/forecast/moonrise-moonset">
#      Moonrise and moonset
#     </a>
#     <a class="menu_seleccionar_ancla menu_seleccionar_ancla_azul" href="https://tides4fishing.com/us/california/south-san-francisco/forecast/uv-exposure-level">
#      UV exposure level
#     </a>
#     <a class="menu_seleccionar_ancla menu_seleccionar_ancla_azul" href="https://tides4fishing.com/us/california/south-san-francisco/forecast/weather">
#      Weather
#     </a>
#     <a class="menu_seleccionar_ancla menu_seleccionar_ancla_azul" href="https://tides4fishing.com/us/california/south-san-francisco/forecast/chance-rain">
#      Chance of rain
#     </a>
#     <a class="menu_seleccionar_ancla menu_seleccionar_ancla_azul" href="https://tides4fishing.com/us/california/south-san-francisco/forecast/temperature">
#      Temperature
#     </a>
#     <a class="menu_seleccionar_ancla menu_seleccionar_ancla_azul" href="https://tides4fishing.com/us/california/south-san-francisco/forecast/humidity">
#      Humidity
#     </a>
#     <a class="menu_seleccionar_ancla menu_seleccionar_ancla_azul" href="https://tides4fishing.com/us/california/south-san-francisco/forecast/visibility">
#      Visibility
#     </a>
#     <a class="menu_seleccionar_ancla menu_seleccionar_ancla_azul" href="https://tides4fishing.com/us/california/south-san-francisco/forecast/atmospheric-pressure">
#      Atmospheric pressure
#     </a>
#     <a class="menu_seleccionar_ancla menu_seleccionar_ancla_azul_seleccionado" href="https://tides4fishing.com/us/california/south-san-francisco/forecast/wind">
#      Wind
#     </a>
#     <a class="menu_seleccionar_ancla menu_seleccionar_ancla_azul" href="https://tides4fishing.com/us/california/south-san-francisco/forecast/surf">
#      Surf
#     </a>
#     <a class="menu_seleccionar_ancla menu_seleccionar_ancla_azul" href="https://tides4fishing.com/us/california/south-san-francisco/forecast/water-temperature">
#      Water temperature
#     </a>
#     <div class="separador_secciones" style="margin-bottom:0">
#     </div>
#     <div id="submenu">
#      <a href="https://tides4fishing.com/us/california/south-san-francisco">
#       <div class="seccion_submenu">
#        <div class="circulo_seccion_submenu">
#         <span class="icon-seccion_submenu1">
#         </span>
#        </div>
#        <div class="nombre_seccion_submenu">
#         Fishing forecast
#        </div>
#       </div>
#      </a>
#      <a href="https://tides4fishing.com/us/california/south-san-francisco/forecast">
#       <div class="seccion_submenu seccion_submenu_select">
#        <div class="circulo_seccion_submenu">
#         <img alt="Weekly forecast South San Francisco" height="27" src="/assets/svg/seccion_submenu7.svg" width="16"/>
#        </div>
#        <div class="nombre_seccion_submenu">
#         Weekly forecast
#        </div>
#       </div>
#      </a>
#      <a href="https://tides4fishing.com/lunar-calendar">
#       <div class="seccion_submenu">
#        <div class="circulo_seccion_submenu">
#         <span class="icon-seccion_submenu4">
#         </span>
#        </div>
#        <div class="nombre_seccion_submenu">
#         Lunar Calendar
#        </div>
#       </div>
#      </a>
#      <a href="https://tides4fishing.com/app">
#       <div class="seccion_submenu">
#        <div class="circulo_seccion_submenu">
#         <span class="icon-seccion_submenu7">
#         </span>
#         <img alt="Help" height="27" src="/assets/svg/app.svg" width="16"/>
#        </div>
#        <div class="nombre_seccion_submenu">
#         App
#        </div>
#       </div>
#      </a>
#      <a href="https://tides4fishing.com/settings">
#       <div class="seccion_submenu">
#        <div class="circulo_seccion_submenu">
#         <span class="icon-seccion_submenu7">
#         </span>
#         <img alt="Help" height="27" src="/assets/svg/settings.svg" width="16"/>
#        </div>
#        <div class="nombre_seccion_submenu">
#         Settings
#        </div>
#       </div>
#      </a>
#      <a href="https://tides4fishing.com/tides">
#       <div class="seccion_submenu">
#        <div class="circulo_seccion_submenu">
#         <span class="icon-seccion_submenu6">
#         </span>
#        </div>
#        <div class="nombre_seccion_submenu">
#         Help
#        </div>
#       </div>
#      </a>
#      <div class="seccion_submenu_justificar">
#      </div>
#     </div>
#     <div id="fin_menu_ancla">
#     </div>
#    </div>
#   </div>
#   <section class="section_lugar_pais">
#    <div id="cabecera_contenido1">
#     <div id="cabecera_contenido1_esquina">
#     </div>
#     <div id="cabecera_h1">
#      <h1>
#       WIND FORECAST
#       <span class="cabecera_h1_subtitulo">
#        South San Francisco
#       </span>
#      </h1>
#     </div>
#    </div>
#    <div id="cabecera_contenido2">
#     <div id="cabecera_contenido2_fondo2">
#     </div>
#     <div id="cabecera_contenido2_banner">
#     </div>
#     <div id="cabecera_contenido3_slogan">
#      <span class="cabecera_contenido2_slogan_span">
#       Forecast in South San Francisco for the next 7 days
#      </span>
#      <div id="cabecera_contenido_slogan3">
#       <span class="cabecera_contenido2_slogan_span">
#        <span id="cabecera_contenido_slogan2_light">
#         FORECAST
#        </span>
#        <span id="cabecera_contenido_slogan2_punto">
#         •
#        </span>
#        7 DAYS
#       </span>
#      </div>
#     </div>
#    </div>
#    <div class="anuncios" id="c_anuncio_banner">
#     <style scoped="">
#      .adslot_1 {display:inline-block; max-width:1200px; max-height:1200px; width: 100%; height: 250px; } @media (min-width: 336px) { .adslot_1 { width: 100%; height: 280px; } } @media (min-width: 728px) { .adslot_1 { width: 728px; height: 90px; } } @media (min-width: 1210px) { .adslot_1 { width: 900px; height: 90px; } }
#     </style>
#     <ins class="adsbygoogle adslot_1" data-ad-client="ca-pub-2382370813209061" data-ad-slot="1067865438" data-full-width-responsive="true">
#     </ins>
#     <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#     </script>
#     <script>
#      (adsbygoogle = window.adsbygoogle || []).push({});
#     </script>
#    </div>
#    <div>
#     <div class="cabecera_seccion cabecera_seccion1" id="mostrar_sticky_to">
#      WIND
#      <div class="cabecera_contenido2_enlace_esquina">
#      </div>
#     </div>
#     <div class="titulo_seccion titulo_seccion_color1">
#      <div class="icono_titulo_seccion color_seccion1">
#       <img alt="	WEATHER FORECAST" class="icon_cabecera_prediccion" src="/assets/svg/seccion_submenu7.svg"/>
#      </div>
#      <div class="cabecera_h2">
#       <h2>
#        WIND PREDICTION
#        <span class="cabecera_h2_subtitulo">
#         SOUTH SAN FRANCISCO
#        </span>
#       </h2>
#      </div>
#      <div class="titulo_seccion_fecha">
#       <div class="titulo_seccion_fecha_texto">
#        NEXT 7 DAYS
#       </div>
#      </div>
#     </div>
#     <form action="https://tides4fishing.com/us/california/south-san-francisco#_weather" id="form_calendario" method="post">
#      <input id="fecha" name="fecha" type="hidden" value=""/>
#     </form>
#     <div class="div_txt_contenido_prevision">
#      <div class="fichas">
#       <div class="ficha">
#        <div class="f_cont">
#         <div class="f_fecha">
#          <div class="f_circulo">
#           <span class="dia">
#            18
#           </span>
#           <span class="mes">
#            APR
#           </span>
#          </div>
#          <div class="f_info_dia">
#           <span class="text_dia">
#            Monday
#           </span>
#           <span class="info">
#            Wind forecast in South San Francisco
#           </span>
#          </div>
#         </div>
#         <div class="f_datos">
#          <table class="tabla_datos_temp">
#           <tr>
#            <td class="f_datos_temp_text">
#             MAX. SPEED
#            </td>
#            <td class="f_dato_color">
#             <div class="f_dato_color1 f_tam1 f_gris_1 f_dato_font_small">
#              12 mph
#             </div>
#            </td>
#           </tr>
#           <tr>
#            <td class="f_datos_temp_text">
#             MIN. SPEED
#            </td>
#            <td class="f_dato_color">
#             <div class="f_dato_color1 f_tam1 f_gris_2 f_dato_font_small">
#              1 mph
#             </div>
#            </td>
#           </tr>
#          </table>
#         </div>
#         <div class="f_text_tiempo">
#          <div class="f_temp_horas">
#           <div class="f_temp_hora">
#            0 h
#           </div>
#           <div class="f_temp_hora">
#            W
#           </div>
#           <div class="f_temp_graf2">
#            <div class="grafico_temp_barra">
#             <div class="grafico_temp_barra_relleno graf_color_velocidad" style="width: 46.206896551724%">
#              4 mph
#             </div>
#            </div>
#           </div>
#          </div>
#          <div class="f_temp_horas">
#           <div class="f_temp_hora">
#            1 h
#           </div>
#           <div class="f_temp_hora">
#            WSW
#           </div>
#           <div class="f_temp_graf2">
#            <div class="grafico_temp_barra">
#             <div class="grafico_temp_barra_relleno graf_color_velocidad" style="width: 50.689655172414%">
#              5 mph
#             </div>
#            </div>
#           </div>
#          </div>
#          <div class="f_temp_horas">
#           <div class="f_temp_hora">
#            2 h
#           </div>
#           <div class="f_temp_hora">
#            W
#           </div>
#           <div class="f_temp_graf2">
#            <div class="grafico_temp_barra">
#             <div class="grafico_temp_barra_relleno graf_color_velocidad" style="width: 43.965517241379%">
#              3 mph
#             </div>
#            </div>
#           </div>
#          </div>
#          <div class="f_temp_horas">
#           <div class="f_temp_hora">
#            3 h
#           </div>
#           <div class="f_temp_hora">
#            W
#           </div>
#           <div class="f_temp_graf2">
#            <div class="grafico_temp_barra">
#             <div class="grafico_temp_barra_relleno graf_color_velocidad" style="width: 39.48275862069%">
#              2 mph
#             </div>
#            </div>
#           </div>
#          </div>
#          <div class="f_temp_horas">
#           <div class="f_temp_hora">
#            4 h
#           </div>
#           <div class="f_temp_hora">
#            W
#           </div>
#           <div class="f_temp_graf2">
#            <div class="grafico_temp_barra">
#             <div class="grafico_temp_barra_relleno graf_color_velocidad" style="width: 35%">
#              1 mph
#             </div>
#            </div>
#           </div>
#          </div>
#          <div class="f_temp_horas">
#           <div class="f_temp_hora">
#            5 h
#           </div>
#           <div class="f_temp_hora">
#            SE
#           </div>
#           <div class="f_temp_graf2">
#            <div class="grafico_temp_barra">
#             <div class="grafico_temp_barra_relleno graf_color_velocidad" style="width: 37.241379310345%">
#              1 mph
#             </div>
#            </div>
#           </div>
#          </div>
#          <div class="f_temp_horas">
#           <div class="f_temp_hora">
#            6 h
#           </div>
#           <div class="f_temp_hora">
#            S
#           </div>
#           <div class="f_temp_graf2">
#            <div class="grafico_temp_barra">
#             <div class="grafico_temp_barra_relleno graf_color_velocidad" style="width: 39.48275862069%">
#              2 mph
#             </div>
#            </div>
#           </div>
#          </div>
#          <div class="f_temp_horas">
#           <div class="f_temp_hora">
#            7 h
#           </div>
#           <div class="f_temp_hora">
#            SSW
#           </div>
#           <div class="f_temp_graf2">
#            <div class="grafico_temp_barra">
#             <div class="grafico_temp_barra_relleno graf_color_velocidad" style="width: 37.241379310345%">
#              1 mph
#             </div>
#            </div>
#           </div>
#          </div>
#          <div class="f_temp_horas">
#           <div class="f_temp_hora">
#            8 h
#           </div>
#           <div class="f_temp_hora">
#            SSE
#           </div>
#           <div class="f_temp_graf2">
#            <div class="grafico_temp_barra">
#             <div class="grafico_temp_barra_relleno graf_color_velocidad" style="width: 43.965517241379%">
#              3 mph
#             </div>
#            </div>
#           </div>
#          </div>
#          <div class="f_temp_horas">
#           <div class="f_temp_hora">
#            9 h
#           </div>
#           <div class="f_temp_hora">
#            SSE
#           </div>
#           <div class="f_temp_graf2">
#            <div class="grafico_temp_barra">
#             <div class="grafico_temp_barra_relleno graf_color_velocidad" style="width: 43.965517241379%">
#              3 mph
#             </div>
#            </div>
#           </div>
#          </div>
#          <div class="f_temp_horas">
#           <div class="f_temp_hora">
#            10 h
#           </div>
#           <div class="f_temp_hora">
#            S
#           </div>
#           <div class="f_temp_graf2">
#            <div class="grafico_temp_barra">
#             <div class="grafico_temp_barra_relleno graf_color_velocidad" style="width: 48.448275862069%">
#              4 mph
#             </div>
#            </div>
#           </div>
#          </div>
#          <div class="f_temp_horas">
#           <div class="f_temp_hora">
#            11 h
#           </div>
#           <div class="f_temp_hora">
#            SW
#           </div>
#           <div class="f_temp_graf2">
#            <div class="grafico_temp_barra">
#             <div class="grafico_temp_barra_relleno graf_color_velocidad" style="width: 48.448275862069%">
#              4 mph
#             </div>
#            </div>
#           </div>
#          </div>
#          <div class="f_temp_horas">
#           <div class="f_temp_hora">
#            12 h
#           </div>
#           <div class="f_temp_hora">
#            SSW
#           </div>
#           <div class="f_temp_graf2">
#            <div class="grafico_temp_barra">
#             <div class="grafico_temp_barra_relleno graf_color_velocidad" style="width: 52.931034482759%">
#              6 mph
#             </div>
#            </div>
#           </div>
#          </div>
#          <div class="f_temp_horas">
#           <div class="f_temp_hora">
#            13 h
#           </div>
#           <div class="f_temp_hora">
#            SSW
#           </div>
#           <div class="f_temp_graf2">
#            <div class="grafico_temp_barra">
#             <div class="grafico_temp_barra_relleno graf_color_velocidad" style="width: 57.413793103448%">
#              7 mph
#             </div>
#            </div>
#           </div>
#          </div>
#          <div class="f_temp_horas">
#           <div class="f_temp_hora">
#            14 h
#           </div>
#           <div class="f_temp_hora">
#            SSW
#           </div>
#           <div class="f_temp_graf2">
#            <div class="grafico_temp_barra">
#             <div class="grafico_temp_barra_relleno graf_color_velocidad" style="width: 59.655172413793%">
#              7 mph
#             </div>
#            </div>
#           </div>
#          </div>
#          <div class="f_temp_horas">
#           <div class="f_temp_hora">
#            15 h
#           </div>
#           <div class="f_temp_hora">
#            SSW
#           </div>
#           <div class="f_temp_graf2">
#            <div class="grafico_temp_barra">
#             <div class="grafico_temp_barra_relleno graf_color_velocidad" style="width: 66.379310344828%">
#              9 mph
#             </div>
#            </div>
#           </div>
#          </div>
#          <div class="f_temp_horas">
#           <div class="f_temp_hora">
#            16 h
#           </div>
#           <div class="f_temp_hora">
#            SW
#           </div>
#           <div class="f_temp_graf2">
#            <div class="grafico_temp_barra">
#             <div class="grafico_temp_barra_relleno graf_color_velocidad" style="width: 73.103448275862%">
#              11 mph
#             </div>
#            </div>
#           </div>
#          </div>
#          <div class="f_temp_horas">
#           <div class="f_temp_hora">
#            17 h
#           </div>
#           <div class="f_temp_hora">
#            SW
#           </div>
#           <div class="f_temp_graf2">
#            <div class="grafico_temp_barra">
#             <div class="grafico_temp_barra_relleno graf_color_velocidad" style="width: 77.586206896552%">
#              12 mph
#             </div>
#            </div>
#           </div>
#          </div>
#          <div class="f_temp_horas">
#           <div class="f_temp_hora">
#            18 h
#           </div>
#           <div class="f_temp_hora">
#            SSW
#           </div>
#           <div class="f_temp_graf2">
#            <div class="grafico_temp_barra">
#             <div class="grafico_temp_barra_relleno graf_color_velocidad" style="width: 77.586206896552%">
#              12 mph
#             </div>
#            </div>
#           </div>
#          </div>
#          <div class="f_temp_horas">
#           <div class="f_temp_hora">
#            19 h
#           </div>
#           <div class="f_temp_hora">
#            SSW
#           </div>
#           <div class="f_temp_graf2">
#            <div class="grafico_temp_barra">
#             <div class="grafico_temp_barra_relleno graf_color_velocidad" style="width: 75.344827586207%">
#              12 mph
#             </div>
#            </div>
#           </div>
#          </div>
#          <div class="f_temp_horas">
#           <div class="f_temp_hora">
#            20 h
#           </div>
#           <div class="f_temp_hora">
#            S
#           </div>
#           <div class="f_temp_graf2">
#            <div class="grafico_temp_barra">
#             <div class="grafico_temp_barra_relleno graf_color_velocidad" style="width: 75.344827586207%">
#              12 mph
#             </div>
#            </div>
#           </div>
#          </div>
#          <div class="f_temp_horas">
#           <div class="f_temp_hora">
#            21 h
#           </div>
#           <div class="f_temp_hora">
#            S
#           </div>
#           <div class="f_temp_graf2">
#            <div class="grafico_temp_barra">
#             <div class="grafico_temp_barra_relleno graf_color_velocidad" style="width: 73.103448275862%">
#              11 mph
#             </div>
#            </div>
#           </div>
#          </div>
#          <div class="f_temp_horas">
#           <div class="f_temp_hora">
#            22 h
#           </div>
#           <div class="f_temp_hora">
#            S
#           </div>
#           <div class="f_temp_graf2">
#            <div class="grafico_temp_barra">
# ...
#       (10 mi.)
#      </span>
#      <span class="lugares_pesca_lugares_separador">
#       |
#      </span>
#      <a href="/us/california/yerba-buena-island/forecast/wind">
#       wind in Yerba Buena Island
#      </a>
#      <span style="color:#999">
#       (10 mi.)
#      </span>
#      <span class="lugares_pesca_lugares_separador">
#       |
#      </span>
#      <a href="/us/california/ocean-beach-outer-coast/forecast/wind">
#       wind in Ocean Beach (Outer Coast)
#      </a>
#      <span style="color:#999">
#       (10 mi.)
#      </span>
#      <span class="lugares_pesca_lugares_separador">
#       |
#      </span>
#      <a href="/us/california/san-leandro-channel-san-leandro-bay/forecast/wind">
#       wind in San Leandro Channel (San Leandro Bay)
#      </a>
#      <span style="color:#999">
#       (10 mi.)
#      </span>
#      <span class="lugares_pesca_lugares_separador">
#       |
#      </span>
#      <a href="/us/california/oakland-inner-harbor/forecast/wind">
#       wind in Oakland Inner Harbor
#      </a>
#      <span style="color:#999">
#       (10 mi.)
#      </span>
#      <span class="lugares_pesca_lugares_separador">
#       |
#      </span>
#      <a href="/us/california/roberts-landing-13-miles-west-of/forecast/wind">
#       wind in Roberts Landing (1.3 Miles West Of)
#      </a>
#      <span style="color:#999">
#       (10 mi.)
#      </span>
#      <span class="lugares_pesca_lugares_separador">
#       |
#      </span>
#      <a href="/us/california/oakland-harbor-grove-street/forecast/wind">
#       wind in Oakland Harbor (Grove Street)
#      </a>
#      <span style="color:#999">
#       (10 mi.)
#      </span>
#      <span class="lugares_pesca_lugares_separador">
#       |
#      </span>
#      <a href="/us/california/oakland-matson-wharf/forecast/wind">
#       wind in Oakland (Matson Wharf)
#      </a>
#      <span style="color:#999">
#       (10 mi.)
#      </span>
#     </p>
#    </div>
#    <div id="social">
#     <a class="social_cuadro" href="https://www.facebook.com/sharer/sharer.php?u=https%3A%2F%2Ftides4fishing.com%2Fus%2Fcalifornia%2Fsouth-san-francisco%2Fforecast%2Fwind" id="social_cuadro_facebook" rel="nofollow" target="_blank" title="share tides for fishing on facebook">
#      <span class="icon-ic_compartir_facebook2">
#       <span class="path1">
#       </span>
#       <span class="path2">
#       </span>
#      </span>
#      <div class="texto_social_cuadro">
#       Facebook
#      </div>
#     </a>
#     <a class="social_cuadro" href="https://twitter.com/share?text=Wind+in+South+San+Francisco.+Wind+forecast+hour+by+hour%2C+wind+speed+and+wind+direction+in+South+San+Francisco." id="social_cuadro_twitter" rel="nofollow" target="_blank" title="share tides for fishing on twitter">
#      <span class="icon-ic_compartir_twitter2">
#       <span class="path1">
#       </span>
#       <span class="path2">
#       </span>
#      </span>
#      <div class="texto_social_cuadro">
#       Twitter
#      </div>
#     </a>
#     <a class="social_cuadro" href="https://pinterest.com/pin/create/button/?url=https%3A%2F%2Ftides4fishing.com%2Fus%2Fcalifornia%2Fsouth-san-francisco%2Fforecast%2Fwind&amp;description=https%3A%2F%2Ftides4fishing.com%2Fus%2Fcalifornia%2Fsouth-san-francisco%2Fforecast%2Fwind&amp;media=https%3A%2F%2Ftides4fishing.com%2Fbanners%2Ftides4fishing_square_250x250.jpg" id="social_cuadro_google" rel="nofollow" target="_blank" title="share tides for fishing on pinterest">
#      <span class="icon-ic_compartir_pinterest2">
#       <span class="path1">
#       </span>
#       <span class="path2">
#       </span>
#      </span>
#      <div class="texto_social_cuadro">
#       Pinterest
#      </div>
#     </a>
#    </div>
#    <div id="lugar_pesca_fondo">
#     <div id="lugar_pesca">
#      <div id="lugar_pesca_texto">
#       Find your fishing location
#      </div>
#      <div id="lugar_pesca_texto2">
#       Find your fishing location
#      </div>
#      <div class="lugar_pesca_boton">
#       <a href="https://tides4fishing.com" rel="nofollow">
#        SEE ALL
#       </a>
#      </div>
#     </div>
#    </div>
#    <div id="pie_fondo">
#     <div id="pie1">
#      <a data-easing="easeInOutCubic" data-scroll="" data-speed="500" data-url="false" href="https://tides4fishing.com/us/california/south-san-francisco/forecast/wind#to_top">
#       <img alt="tide table" class="cursor_up" id="logo_pie" src="/assets/svg/logo_en.svg"/>
#      </a>
#      <div class="pie_separar_pocos_enlaces" id="pie1_enlaces1">
#       <a href="https://tides4fishing.com/us/california/south-san-francisco">
#        TIDE TABLE &amp; SOLUNAR CHARTS
#       </a>
#       <a href="https://tides4fishing.com/lunar-calendar">
#        LUNAR CALENDAR
#       </a>
#      </div>
#      <div class="pie_separar_pocos_enlaces2" id="pie1_enlaces2">
#       <a href="https://tides4fishing.com/manual" rel="nofollow">
#        OPERATION MANUAL
#       </a>
#       <a href="https://tides4fishing.com/logos" rel="nofollow">
#        LINK TIDES4FISHING
#       </a>
#       <a href="https://tides4fishing.com/contact" rel="nofollow">
#        FAQ &amp; CONTACT
#       </a>
#       <a href="https://tides4fishing.com/app">
#        APP
#       </a>
#      </div>
#     </div>
#     <div id="pie2_fondo">
#      <div id="pie2">
#       <div class="pie2_enlaces1_fondo">
#        <div id="pie2_enlaces1">
#         <div class="pie2_enlaces_titulo">
#          UNDERSTANDING THE TIDES
#         </div>
#         <a href="https://tides4fishing.com/tides">
#          Tides
#         </a>
#         <a href="https://tides4fishing.com/tides/types-of-tides">
#          Types of tides
#         </a>
#         <a href="https://tides4fishing.com/tides/tidal-coefficient">
#          Tidal coefficient
#         </a>
#         <a href="https://tides4fishing.com/tides/tide-currents">
#          Tide currents
#         </a>
#         <a href="https://tides4fishing.com/tides/tides-in-rivers">
#          Tides in rivers
#         </a>
#         <a href="https://tides4fishing.com/tides/tides-universe">
#          The tides in the universe
#         </a>
#         <a href="https://tides4fishing.com/tides/how-tides-are-forecast">
#          How tides are forecast
#         </a>
#        </div>
#       </div>
#       <div class="pie2_enlaces1_fondo">
#        <div id="pie2_enlaces2">
#         <div class="pie2_enlaces_titulo">
#          SOLUNAR CHARTS
#         </div>
#         <a href="https://tides4fishing.com/solunar-tables">
#          Solunar charts
#         </a>
#         <a href="https://tides4fishing.com/solunar-tables/solunar-theory">
#          The solunar theory
#         </a>
#         <a href="https://tides4fishing.com/solunar-tables/relation-tides-solunar-tables">
#          Solunar-Tidal Relation
#         </a>
#         <a href="https://tides4fishing.com/solunar-tables/conclusion">
#          Conclusion
#         </a>
#        </div>
#       </div>
#       <div style="clear:both">
#       </div>
#      </div>
#     </div>
#     <div id="pie3">
#      <div id="pie3_texto">
#       Share a day of fishing with friends
#      </div>
#      <div id="pie3_enlaces_compartir">
#       <div class="pie3_enlace boton_whatsapp">
#        <a class="" href="whatsapp://send?text=Wind+in+South+San+Francisco.+Wind+forecast+hour+by+hour%2C+wind+speed+and+wind+direction+in+South+San+Francisco.+%F0%9F%8E%A3+tides4fishing.com%2Fus%2Fcalifornia%2Fsouth-san-francisco%2Fforecast%2Fwind" rel="nofollow" target="_blank" title="share tides for fishing on whatsapp">
#         <span class="icon-ic_compartir_whatsapp icono">
#          <span class="path1">
#          </span>
#          <span class="path2">
#          </span>
#         </span>
#         <span>
#          <span class="icon-ic_compartir_whatsapp2 icono oculto">
#           <span class="path1">
#           </span>
#           <span class="path2">
#           </span>
#          </span>
#         </span>
#        </a>
#       </div>
#       <div class="pie3_enlace">
#        <a class="" href="https://twitter.com/share?text=Wind+in+South+San+Francisco.+Wind+forecast+hour+by+hour%2C+wind+speed+and+wind+direction+in+South+San+Francisco." rel="nofollow" target="_blank" title="share tides for fishing on twitter">
#         <span class="icon-ic_compartir_twitter icono">
#          <span class="path1">
#          </span>
#          <span class="path2">
#          </span>
#         </span>
#         <span>
#          <span class="icon-ic_compartir_twitter2 icono oculto">
#           <span class="path1">
#           </span>
#           <span class="path2">
#           </span>
#          </span>
#         </span>
#        </a>
#       </div>
#       <div class="pie3_enlace">
#        <a class="" href="https://www.facebook.com/sharer/sharer.php?u=https%3A%2F%2Ftides4fishing.com%2Fus%2Fcalifornia%2Fsouth-san-francisco%2Fforecast%2Fwind" rel="nofollow" target="_blank" title="share tides for fishing on facebook">
#         <span class="icon-ic_compartir_facebook icono">
#          <span class="path1">
#          </span>
#          <span class="path2">
#          </span>
#         </span>
#         <span>
#          <span class="icon-ic_compartir_facebook2 icono oculto">
#           <span class="path1">
#           </span>
#           <span class="path2">
#           </span>
#          </span>
#         </span>
#        </a>
#       </div>
#       <div class="pie3_enlace">
#        <a class="" href="https://pinterest.com/pin/create/button/?url=https%3A%2F%2Ftides4fishing.com%2Fus%2Fcalifornia%2Fsouth-san-francisco%2Fforecast%2Fwind&amp;description=Wind+in+South+San+Francisco.+Wind+forecast+hour+by+hour%2C+wind+speed+and+wind+direction+in+South+San+Francisco.&amp;media=https%3A%2F%2Ftides4fishing.com%2Fbanners%2Ftides4fishing_square_250x250.jpg" rel="nofollow" target="_blank" title="share tides for fishing on pinterest">
#         <span class="icon-ic_compartir_pinterest icono">
#          <span class="path1">
#          </span>
#          <span class="path2">
#          </span>
#         </span>
#         <span>
#          <span class="icon-ic_compartir_pinterest2 icono oculto">
#           <span class="path1">
#           </span>
#           <span class="path2">
#           </span>
#          </span>
#         </span>
#        </a>
#       </div>
#       <div class="pie3_enlace">
#        <a class="" href="https://tides4fishing.com/recommend-friend?url=https://tides4fishing.com/us/california/south-san-francisco/forecast/wind" rel="nofollow" title="Send to a friend tides 4 fishing">
#         <span class="icon-ic_compartir_email icono">
#          <span class="path1">
#          </span>
#          <span class="path2">
#          </span>
#         </span>
#         <span>
#          <span class="icon-ic_compartir_email2 icono oculto">
#           <span class="path1">
#           </span>
#           <span class="path2">
#           </span>
#          </span>
#         </span>
#        </a>
#       </div>
#      </div>
#     </div>
#     <div class="nautide">
#      <div class="linea_top">
#      </div>
#      <div class="nautide2">
#       <div class="nautide_content">
#        <a href="/app" rel="nofollow" title="nautide">
#         <img alt="nautide app icon" class="logo_nautide" src="/assets/img/nautide/nautide.svg"/>
#        </a>
#        <div class="nautide_name">
#         <a href="/app" rel="nofollow" title="nautide">
#          <img alt="nautide" class="name_nautide" src="/assets/img/nautide/nautide_name.svg"/>
#         </a>
#        </div>
#        <div class="nautide_description">
#         Plan now and enjoy your activities at sea with the tides4fishing app
#        </div>
#       </div>
#       <div class="nautide_content2">
#        <div class="nautide_puntuacion">
#         <div class="nautide_puntuacion_estrellas">
#          <img alt="app" class="usuario_puntuacion" src="/assets/img/nautide/usuario.svg"/>
#          <img alt="app" class="estrella_puntuacion" src="/assets/img/nautide/estrella.svg"/>
#          <img alt="app" class="estrella_puntuacion" src="/assets/img/nautide/estrella.svg"/>
#          <img alt="app" class="estrella_puntuacion" src="/assets/img/nautide/estrella.svg"/>
#          <img alt="app" class="estrella_puntuacion" src="/assets/img/nautide/estrella.svg"/>
#          <img alt="app" class="estrella_puntuacion" src="/assets/img/nautide/estrella_media.svg"/>
#         </div>
#        </div>
#        <div class="botones_market">
#         <a href="https://play.google.com/store/apps/details?id=com.nautide.app" title="Download tides 4 fishing App on Google Play">
#          <img alt="google play" class="market_button1 lazyload" data-src="/assets/img/nautide/google_play.svg"/>
#         </a>
#         <a href="https://apps.apple.com/us/app/nautide/id1413108902" title="Download tides 4 fishing App on App Store">
#          <img alt="app store" class="market_button2 lazyload" data-src="/assets/img/nautide/app_store.svg"/>
#         </a>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div id="pie4">
#      <div id="pie4_idiomas">
#       <img alt="" class="pie4_idiomas_img" src="/assets/svg/ico_idioma_interfaz.svg"/>
#       <select name="select_idiomas" onchange="CambiarIdioma(this)">
#        <option selected="" value="https://tides4fishing.com">
#         English
#        </option>
#        <option value="https://tablademareas.com">
#         Spanish
#        </option>
#        <option value="https://mareespeche.com">
#         French
#        </option>
#        <option value="https://tabuademares.com">
#         Portuguese
#        </option>
#        <option value="https://meteopesca.com">
#         Italian
#        </option>
#        <option value="https://gezeitenfisch.com">
#         German
#        </option>
#        <option value="https://choseki.com">
#         Japanese
#        </option>
#        <option value="https://haichaobiao.com">
#         Chinese
#        </option>
#        <option value="https://prilivy.com">
#         Russian
#        </option>
#        <option value="https://pasanglaut.com">
#         Indonesian
#        </option>
#        <option value="https://almadwaaljazer.com">
#         Arabic
#        </option>
#        <option value="https://multtaepyo.com">
#         Korean
#        </option>
#        <option value="https://cau-ca.com">
#         Vietnamese
#        </option>
#       </select>
#      </div>
#      <div id="pie4_copy">
#       <a href="https://tides4fishing.com/legal-notice" rel="nofollow">
#        Copyright ©2022 tides4fishing.
#       </a>
#      </div>
#      <div id="pie4_derechos">
#       All rights reserved.
#       <a href="https://tides4fishing.com/legal-notice" rel="nofollow">
#        Legal notice
#       </a>
#      </div>
#     </div>
#     <div id="cookies_pie">
#      <div id="texto_cookies2">
#       Tides4fishing
#       <strong>
#        cookies
#       </strong>
#       are used to personalise content and ads, save your recent fishing sites and remember your display settings. We also share information about your use of our site with our social media, advertising and analytics partners.
#      </div>
#      <div id="botones_cookies2">
#       <a href="https://tides4fishing.com/legal-notice">
#        See details
#       </a>
#       <a onclick="CerrarCookies();" style="margin-left:7px">
#        OK
#       </a>
#      </div>
#     </div>
#    </div>
#   </section>
#   <script>
#    var JS_ANCLA_B1_S1 = "_forecast";	var JS_ANCLA_B1_S2 = "_weather_map";	var JS_ANCLA_B1_S3 = "_temperatura_agua";
#   </script>
#   <script>
#    var JS_APARTADO="prevision";var JS_REACTIVAR_SWIPE_CERRAR_PANEL=false;var JS_CABECERA_OFFSET=160;var JS_TIENE_PANEL_MOVIL=true;var JS_TIENE_SUBMENU=true;var JS_CLASS_HEADER="header_reducido";var JS_MODO_TEST_ANUNCIOS=false;
#   </script>
#   <script src="/assets/js/share/scroll.min.js?v=7.3">
#   </script>
#   <script src="/assets/js/share/panel.min.js?v=7.3">
#   </script>
#   <script src="/assets/js/share/onload.min.js?v=7.3">
#   </script>
#   <script src="/assets/js/share/to_top.min.js?v=7.3">
#   </script>
#   <script>
#    ( function ( i, s, o, g, r, a, m ) {
#                 i[ 'GoogleAnalyticsObject' ] = r;
#                 i[ r ] = i[ r ] || function () {
#                     ( i[ r ].q = i[ r ].q || [] ).push( arguments )
#                 }, i[ r ].l = 1 * new Date();
#                 a = s.createElement( o ), m = s.getElementsByTagName( o )[ 0 ];
#                 a.async = 1;
#                 a.src = g;
#                 m.parentNode.insertBefore( a, m )
#             } )( window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga' );
#             ga( 'create', 'UA-8166479-2', 'auto' );
#             ga( 'send', 'pageview' );
#   </script>
#  </body>
# </html>

# %%
print(doc.get_text())
# Out:
#  Wind in South San Francisco. Wind forecast hour by hour, wind speed and wind direction in South San Francisco.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Tides4fishing cookies are used to personalise content and ads, save your recent fishing sites and remember your display settings. We also share information about your use of our site with our social media, advertising and analytics partners.
#   See details   OK
#
#     North AmericaUnited StatesCaliforniaSouth San Francisco   Settings   Change language EnglishSpanishFrenchPortugueseItalianGermanJapaneseDate and Time Settings Date Formatdd/mm/yyyymm/dd/yyyyyyyy/mm/ddFirst day of the weekMondaySundayTime format  (12-hour / 24-hour)12-hour  (am/pm)24-hourDefault units Height of the tidesMeters (m)Feet (ft)Weather units°C, km/h, hPa°F, mph, inchesDistance between starskilometers (km)Astronomic unit (AU)My recent sitesSouth San FranciscoWEEKLY FORECAST UTC-7California (	US)time change202 days (UTC -8)   Weekly forecastTidesFishingSunrise and sunsetMoonrise and moonset UV exposure level WeatherChance of rainTemperatureHumidityVisibilityAtmospheric pressureWindSurfWater temperature     Fishing forecast  Weekly forecast      Lunar Calendar        App        Settings        Help   WIND FORECASTSouth San FranciscoForecast in South San Francisco for the next 7 daysFORECAST • 7 DAYS   WIND WIND PREDICTIONSOUTH SAN FRANCISCONEXT 7 DAYS18APRMondayWind forecast in South San FranciscoMAX. SPEED12 mph MIN. SPEED1 mph 0 hW4 mph 1 hWSW5 mph 2 hW3 mph 3 hW2 mph 4 hW1 mph 5 hSE1 mph 6 hS2 mph 7 hSSW1 mph 8 hSSE3 mph 9 hSSE3 mph 10 hS4 mph 11 hSW4 mph 12 hSSW6 mph 13 hSSW7 mph 14 hSSW7 mph 15 hSSW9 mph 16 hSW11 mph 17 hSW12 mph 18 hSSW12 mph 19 hSSW12 mph 20 hS12 mph 21 hS11 mph 22 hS11 mph 23 hS11 mph + INFO19APRTuesdayWind forecast in South San FranciscoMAX. SPEED11 mph MIN. SPEED3 mph 0 hS11 mph 1 hS11 mph 2 hSSW9 mph 3 hSSW7 mph 4 hSW6 mph 5 hWSW5 mph 6 hW5 mph 7 hW3 mph 8 hWNW4 mph 9 hWNW3 mph 10 hW4 mph 11 hWNW5 mph 12 hW5 mph 13 hW7 mph 14 hW8 mph 15 hW9 mph 16 hW9 mph 17 hW9 mph 18 hW9 mph 19 hW7 mph 20 hWNW6 mph 21 hWNW6 mph 22 hW5 mph 23 hW3 mph + INFO20APRWednesdayWind forecast in South San FranciscoMAX. SPEED17 mph MIN. SPEED3 mph 0 hSSW3 mph 1 hSSW3 mph 2 hS5 mph 3 hS5 mph 4 hS6 mph 5 hSSE7 mph 6 hSSE9 mph 7 hSSE9 mph 8 hSSE10 mph 9 hS12 mph 10 hS14 mph 11 hS16 mph 12 hSSW17 mph 13 hSSW16 mph 14 hSSW17 mph 15 hSSW17 mph 16 hSSW17 mph 17 hSSW14 mph 18 hSSW17 mph 19 hSSW16 mph 20 hSSW14 mph 21 hSSW14 mph 22 hSSW14 mph 23 hSSW13 mph + INFO21APRThursdayWind forecast in South San FranciscoMAX. SPEED14 mph MIN. SPEED4 mph 0 hSW12 mph 1 hSW10 mph 2 hSW9 mph 3 hWSW8 mph 4 hW6 mph 5 hW5 mph 6 hSSW4 mph 7 hSW5 mph 8 hWSW6 mph 9 hWSW6 mph 10 hWSW5 mph 11 hWSW7 mph 12 hWSW9 mph 13 hWSW12 mph 14 hWSW13 mph 15 hWSW14 mph 16 hWSW14 mph 17 hWSW13 mph 18 hWSW12 mph 19 hWSW11 mph 20 hWSW9 mph 21 hWSW7 mph 22 hSW7 mph 23 hSW7 mph + INFO22APRFridayWind forecast in South San FranciscoMAX. SPEED12 mph MIN. SPEED2 mph 0 hSW7 mph 1 hWSW6 mph 2 hWSW6 mph 3 hWSW5 mph 4 hSW4 mph 5 hSW3 mph 6 hWSW2 mph 7 hSW2 mph 8 hWSW2 mph 9 hW4 mph 10 hWNW6 mph 11 hW7 mph 12 hW9 mph 13 hW11 mph 14 hW11 mph 15 hW12 mph 16 hW12 mph 17 hW12 mph 18 hWNW12 mph 19 hWNW11 mph 20 hWNW10 mph 21 hWNW9 mph 22 hWNW9 mph 23 hWNW8 mph + INFO23APRSaturdayWind forecast in South San FranciscoMAX. SPEED15 mph MIN. SPEED3 mph 0 hWNW7 mph 1 hWNW7 mph 2 hWNW6 mph 3 hNW6 mph 4 hNW5 mph 5 hNW4 mph 6 hNW4 mph 7 hNNW4 mph 8 hNNW4 mph 9 hNNW4 mph 10 hNW4 mph 11 hNW3 mph 12 hWNW6 mph 13 hWNW8 mph 14 hWNW11 mph 15 hWNW12 mph 16 hWNW13 mph 17 hWNW15 mph 18 hWNW14 mph 19 hWNW12 mph 20 hWNW11 mph 21 hWNW9 mph 22 hNW7 mph 23 hNW5 mph + INFO24APRSundayWind forecast in South San FranciscoMAX. SPEED12 mph MIN. SPEED2 mph 0 hNW4 mph 1 hWNW4 mph 2 hWNW4 mph 3 hWNW4 mph 4 hNW3 mph 5 hNW3 mph 6 hWSW2 mph 7 hSSE2 mph 8 hENE2 mph 9 hSSE2 mph 10 hWSW2 mph 11 hNNW2 mph 12 hNNW5 mph 13 hNW7 mph 14 hWNW9 mph 15 hWNW11 mph 16 hWNW11 mph 17 hWNW12 mph 18 hWNW11 mph 19 hWNW9 mph 20 hWNW8 mph 21 hWNW7 mph 22 hWNW6 mph 23 hNW4 mph + INFO E-mail Pinterest Facebook Twitter Whatsapp © TIDES4FISHING | WEATHER FORECAST IN SOUTH SAN FRANCISCO | NEXT 7 DAYS      FISHING SITES CLOSE TO SOUTH SAN FRANCISCO wind in Oyster Point Marina (0.7 mi.) | wind in Point San Bruno (1.4 mi.) | wind in Seaplane Harbor (2.1 mi.) | wind in Hunters Point (5 mi.) | wind in Potrero Point (6 mi.) | wind in Coyote P ...

# %%
#find all 1h times, monday through friday
clock = doc.find_all(text="1 h")
#finding windspeed associated with that time
parent = clock[0].parent
print(clock)
print(parent)
direction = parent.next_sibling
print(direction)
speed = direction.next_sibling
print(speed.string)
# Out:
# ['1 h', '1 h', '1 h', '1 h', '1 h', '1 h', '1 h']
# <div class="f_temp_hora">1 h</div>
# <div class="f_temp_hora">WSW</div>
# 5 mph

# %%
#windspeed = wind speeds at 1am monday through sunday
#windspeed2 = wind speeds at 1pm monday through sunday

actual_speeds = []
print(actual_speeds)
for i in range(7):
    parent = clock[i].parent
    direction = parent.next_sibling
    speed = direction.next_sibling
    actual_speeds.append(speed.string)
    
print(actual_speeds)
# Out:
# []
# ['5 mph', '11 mph', '3 mph', '10 mph', '6 mph', '7 mph', '4 mph']

# %%
# where hour is the desired hour of the day to retrieve windspeeds from across the week

def get_speeds(hour):
        time = []
        hour = str(hour) + " h"
        clock = doc.find_all(text=hour)
        for i in range(7):
            parent = clock[i].parent
            direction = parent.next_sibling
            speed = direction.next_sibling
            time.append(speed.string)
        print(time)
        return time
    
Night = get_speeds(1)
Midday = get_speeds(13)

type(Night)
# Out:
# ['5 mph', '11 mph', '3 mph', '10 mph', '6 mph', '7 mph', '4 mph']
# ['7 mph', '7 mph', '16 mph', '12 mph', '11 mph', '8 mph', '7 mph']
# list

# %%
#clean data

Night = get_speeds(1)


def clean_data(data):
    for i in range(7):
        data[i] = int(data[i].replace(" mph", ""))
    return data

clean_data(Night)        
print(Night)
clean_data(Midday)
print(Midday)
# Out:
# ['5 mph', '11 mph', '3 mph', '10 mph', '6 mph', '7 mph', '4 mph']
# [5, 11, 3, 10, 6, 7, 4]
# [7, 7, 16, 12, 11, 8, 7]

# %%
#Plotting a graph with extracted data
import matplotlib.pyplot as plt
from statistics import mean

night = mean(Night)
midday = mean(Midday)


fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
time = ["Night", "Midday"]
value = [night, midday]
ax.bar(time,value)
ax.set_ylabel("Average windspeed (mph)")
print(plt.show())
# Out:
# None
